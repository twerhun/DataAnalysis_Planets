# %% [markdown]
# # Could Star Wars planets exist in our universe?
# <img src="https://www.starwarsnewsnet.com/wp-content/uploads/2020/09/Mando_Season_2_Trailer_01.png"><p style='text-align: right'> Source: www.starwarsnewsnet.com </p>
#
# ## Part 1. Data scraping

# %% [markdown]
# ### Table of contents:
# 1. Introduction
# 2. Goal
# 3. Data scraping
# 4. Summary

# %% [markdown]
# ## 1. Introduction
#
# Some time ago I watched an interesting documentary about planets beyond our solar system - how they were discovered, how much data about them we are able to collect and how life on some of those planets could possibly look like. This immiedietly woke my nerd instincts and I started to wonder - could planets that we know from science fiction universe such as Star Wars exist in our universe? After all it all happened *a long time ago, in a galaxy far, far away...*
#
# Well, ok - probably not. I am not THAT obsessed. But there can certainly exist similar planets.
#
# Based on data that we are able to collect from both Star Wars fictional universe and our real life universe I decided to look for corresponding information that we can actually compare. With those information we will be able to find the most similar planets from both of those universes. This could be an interesting experiment!
#
# This project will be divided into two parts. In this part I will prepare data frames by scraping data from **wikipedia** and **wookieepedia** (wikipedia for star wars), which will be used in part 2, where they will be cleaned and analysed.

# %% [markdown]
# ## 2. Goal
#
# In this part we will need to create two dataframes following this scheme:
# - find list of planets on wikipedia/wookieepedia
# - create iterable list of planets
# - find representative planet
# - define which data we want to collect
# - gather selected data from all sites about planets on wikipedia/wookiepedia
# - create dataframes based on collected data
# - clear collected data (pre-cleaning, mainly getting rid of typical wiki indexes)
# - save created dataframes as csv files

# %% [markdown]
# ## 3. Data scraping
#
# For this part I will mainly explore possibilities of Bautiful Soup library. This is very useful tool that helps with gathering data from html and xml sites. From documentation:
# <blockquote>Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.</blockquote>
# You can read more about Beautiful Soup <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc"><b>HERE</b></a>
#
# During this proces we will gather data from <a href="https://en.wikipedia.org/wiki/Main_Page">wikipedia</a> and <a href="https://starwars.fandom.com/wiki/Main_Page">wookiepedia</a>. For more detailed information I encourage you to check on them.
#
# Without further ado let's start our process with importing some libraries. In addition to core libraries I decided to import time library as well to check how long it took to collect main data about planets

# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# First of all we will need list of all Star Wars planets. I have found one <a href="https://starwars.fandom.com/wiki/List_of_planets?so=search">here</a>. As you can notice, the thing that distinguish planet name from other elements on this site is: being a **link** (so it posses html **'a' tag**) and being **bold** (html **'b' tag**). We can search and list all elements meeting those conditions **except first element**, which happen to be word "planets" (just under title and canon/legends buttons).

# %%
page = requests.get('https://starwars.fandom.com/wiki/List_of_planets?so=search')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
planets = []
#dropping first element, because it's the name of the category - "planets"
for i in soup.find_all('b')[2:]:
    try:
        planets.append(i.a.get('title'))
    except:
        continue
planets
# Out:
# ['5251977',
#  'Aargonar',
#  'Ab Dalis',
#  'Abafar',
#  'Abednedo (planet)',
#  'Abelor',
#  'Abregado-rae',
#  'Absanz',
#  'Actlyon',
#  'Aeos Prime',
#  'Affa',
#  'Affadar',
#  'Agamar',
#  'Agaris',
#  'Agoliba-Ado',
#  'Agoliba-Ena',
#  'Ahch-To',
#  'Ajara',
#  'Akiva',
#  'Alaris',
#  'Alderaan',
#  'Aleen',
#  'Aleen Minor',
#  'Allst Prime',
#  'Allyuen',
#  'Aloxor',
#  'Alpinn',
#  'Alsakan',
#  'Alun',
#  'Ambria',
#  'Amethia Prime',
#  'Ammon IV',
#  'Anantapar',
#  'Anaxes',
#  'Andelm IV',
#  'Ando',
#  'Ando Prime',
#  'Anelsana',
#  'Ankhural',
#  'Anoat',
#  'Ansion',
#  'Antar',
#  'Anthan Prime',
#  'Aquaris',
#  'Aq Vetina',
#  'Arbiflux',
#  'Arbooine',
#  'Ardennia',
#  'Argai Minor',
#  'Aria Prime',
#  'Aridus',
#  'Arieli',
#  'Arkanis',
#  'Aris',
#  'Arreyel',
#  'Artiod Minor',
#  'Arvala-7',
#  'Ashas Ree',
#  'Askaji',
#  'Asmeru',
#  'Asusto',
#  'Athulla',
#  'Atollon',
#  'Atterra Alpha',
#  'Atterra Bravo',
#  'Atterra Primo',
#  'Auratera',
#  'Avedot',
#  'Avidich',
#  'Axxila',
#  'Bakura',
#  'Balnab',
#  'Balosar',
#  'Bamayar IX',
#  "B'ankora homeworld",
#  'Baraan-Fa',
#  'Barab I',
#  'Bardelberan 7',
#  'Bardotta',
#  "Bar'leth",
#  'Bastatha',
#  'Basteel',
#  'Batonn',
#  'Batuu',
#  'Bavva',
#  'Bedlam',
#  'Begamore',
#  'Behpour',
#  'Belderone',
#  'Bendeluum',
#  'Benetage',
#  'Benglor',
#  'Bernilla',
#  'Berzite',
#  'Bespin',
#  'Bestine IV',
#  'Bilzen',
#  'Birren',
#  'Bith (planet)',
#  'Blutopia',
#  'Bogano',
#  'Bora Vio',
#  'Botajef',
#  'Bothawui',
#  'Botor',
#  'Boz Pity',
#  'Bracca',
#  'Bray',
#  'Brentaal IV',
#  "Bri'n",
#  'Bromlarch',
#  'Burnin Konn',
#  'Cabarria',
#  'Cadomai Prime',
#  'Calcoraan',
#  'Caloria',
#  'Camson',
#  'Candovant',
#  'Cantonica',
#  'Caragon-Viner',
#  'Carajam',
#  'Cardota',
#  'Carida',
#  'Carlac',
#  'Carnelion IV',
#  'Castell',
#  'Castilon',
#  'Catadra',
#  'Cato Neimoidia',
#  'Cavas',
#  'Celwis',
#  'Cerea',
#  'Cermau',
#  'CeSai',
#  'Chaaktil',
#  'Chad',
#  'Chadawa',
#  'Chagar IX',
#  'Chal Hudda',
#  'Chalacta',
#  'Champala',
#  "Chandar's Folly",
#  'Chandel',
#  'Chandrila',
#  'Chasmeene',
#  'Chibbier',
#  'Cholganna',
#  'Chommell Minor',
#  'Chorin',
#  'Christophsis',
#  'Chrona',
#  'Cianap',
#  'Clerion',
#  'Codia',
#  'Colla IV',
#  'Commenor',
#  'Cona',
#  'Concord Dawn',
#  "The Contessa's homeworld",
#  'Corellia',
#  'Corulag',
#  'Coruscant',
#  'Corvus',
#  'Cos Secundu',
#  'Cosia',
#  'Cosmatanic Steppes gas giant',
#  'Council (planet)',
#  'Courtsilius',
#  'Coyerti',
#  'Crait',
#  'Crucival',
#  'Crul',
#  'Csilla',
#  'Cuyacan',
#  'Cyclor',
#  'Cyphar',
#  'Cyrkon',
#  'Czerialus',
#  'Daghee',
#  'Dagobah',
#  'Daivak',
#  'Dallenor',
#  'Dalna',
#  'Dandoran',
#  'Dantooine',
#  'Darlyn Boda',
#  'Daro',
#  'Dasoor',
#  'Dathomir',
#  'Davnar II',
#  'Daxam IV',
#  'Daxan Beta',
#  'The Deep',
#  'Delphon',
#  'Delrian Prison Planet',
#  'Demir',
#  'Denash',
#  'Denon',
#  'Dermos',
#  'Devaron',
#  'Dhandu',
#  'Dianth',
#  'Dinwa Prime',
#  'Dinzo',
#  'Distilon',
#  "Dol'har Hyde",
#  'Dorin',
#  'Dowut',
#  "D'Qar",
#  'Drahgor III',
#  'Durkteel',
#  'Duro',
#  'Dwartii',
#  'Dybbron III',
#  'Dybrin',
#  'Eadu',
#  'Earth',
#  'Edis VII',
#  'Egips',
#  'Eiram',
#  'Elkeenar',
#  'Elom (planet)',
#  'Elphrona',
#  'Empress Teta',
#  'Endor (planet)',
#  'Epiphany',
#  'Eriadu',
#  "Er'Kit",
#  "E'ronoh",
#  'Eroudac',
#  'Ertegas',
#  'Eshan',
#  'Espinar',
#  'Espirion',
#  'Esseles',
#  'Etti IV',
#  'Eufornis Major',
#  'Eufornis Minor',
#  'Exegol',
#  'Ezaraa (planet)',
#  'Falleen (planet)',
#  'Farhava Beta',
#  'Fedalle',
#  'Fedovoi End',
#  'Feenix',
#  'Felucia',
#  'Fermic',
#  'Fest',
#  'Fillithar (planet)',
#  'Florrum',
#  'Fondor',
#  'Foran Tutha',
#  'Frong (planet)',
#  'Gaaten',
#  'Gabdor',
#  'Galaan',
#  'Galagolos V',
#  'Galator III',
#  'Galidraan',
#  'Galidraan III',
#  'Galidraan IV',
#  'Galmerah',
#  'Galpos II',
#  'Galzez',
#  'Gamerong',
#  'Gamorr',
#  'Gan Moradir',
#  'Gand (planet)',
#  'Ganthel',
#  'Garel',
#  'Gargon',
#  'Gatalenta',
#  'Gentes',
#  'Geonosis',
#  'Gerrenthum',
#  'Gesaral Beta',
#  'Ghorman',
#  'Gigor',
#  'Giju',
#  'Gilvaanen',
#  'Glee Anselm',
#  'Gonda',
#  'Gorse',
#  'Gossam (planet)',
#  'Graf-World',
#  'Grange',
#  'Grizal',
#  'Grizmallt',
#  'Guagenia',
#  "Guat'a",
#  'GUHL-JO387O',
#  'Gutretee',
#  'Gwongdeen',
#  'Gyndine',
#  'Hadros',
#  'Haidoral Prime',
#  'Haileap',
#  'Halcyon',
#  'Haneli',
#  'Harkrova I',
#  'Harloff Minor',
#  'Haruun Kal',
#  'Hays Major',
#  'Hays Minor',
#  'Hetzal Prime',
#  'Hevurion',
#  'Hinari',
#  'Hirara',
#  'Hisseen',
#  'Hissrich',
#  'Horuz',
#  'Hosnian',
#  'Hosnian Prime',
#  'Hosra',
#  'Hoth',
#  'Hovun IV',
#  'Hoxim',
#  'Hudalla',
#  'Humbarine',
#  'Hynestia',
#  'Iakar',
#  'Ibaar',
#  'Iego',
#  'Ikkrukk',
#  'Iktotchon',
#  'Iloh',
#  'Ilum',
#  'Imroosia',
#  'Imvur',
#  'Indoumodo',
#  'Insk',
#  'Inusagi',
#  'Ione',
#  'Irff',
#  'Iridonia',
#  'Irudiru',
#  'Iskalon',
#  'Isobe',
#  'Ison',
#  'Itapi Prime',
#  'Ithor',
#  'Ivarujar',
#  'Ivera X',
#  "I'vorcia Prime",
#  'Ixilix',
#  'Jaelen',
#  'Jafan (planet)',
#  'Jaguada',
#  'Jakku',
#  'Jalindi',
#  'Japeal',
#  'Jarbanov',
#  'Jaresh',
#  'Jaymir',
#  'Jekara',
#  'Jelucan',
#  'Jeosyn',
#  'Jestefad',
#  'Jeyell',
#  'Jhas',
#  'Jiruus',
#  'Judakann',
#  'K43',
#  'Kadavo',
#  'Kaddak',
#  'Kalee',
#  'Kalevala',
#  'Kaller',
#  "Kal'Shebbol",
#  'Kamino',
#  'Kanzi',
#  'Kardoa',
#  'Karfeddion',
#  'Karkaris',
#  'Karlinus',
#  'Kartoosh',
#  'Kashyyyk',
#  'Keitum',
#  'Kellux',
#  'Kerev Doi',
#  'Kergans',
#  'Kerkoidia',
#  'Kessel',
#  'Kethmandi',
#  'Ketzali',
#  'Kidron',
#  'Kiffex',
#  'Kiffu',
#  'Kijimi',
#  'Kinoss',
#  'Kinrah',
#  'Kintan',
#  'Kintoni',
#  'Kinyen',
#  'Kirdo III',
#  'Kiros',
#  'Kirtarkin',
#  'Kizan',
#  'Klatooine',
#  'Klonoid',
#  'Klytus V',
#  'Kol Iben',
#  'Konkiv',
#  'Kooriva',
#  'Koorivar homeworld',
#  'Kortatka',
#  'Koshaga',
#  'Kotab',
#  'Kowak',
#  'Kreeling',
#  "Kril'Dor",
#  'Krownest',
#  'Krystar',
#  "Ktath'atn",
#  'Kuat',
#  'Kubindi',
#  'Kudo',
#  'Kullgroon',
#  'Kupoh',
#  'Lafete',
#  "Lah'mu",
#  'Lahn',
#  'Lannik',
#  'Lanteeb',
#  'Lanz Carpo',
#  'Lasan',
#  'Lateron',
#  'Lefrani',
#  'Leoxo',
#  'Lespectus',
#  "Lew'el",
#  'Lexrul',
#  'Lioaoin heartworld',
#  'Lira San',
#  'Li-Toran',
#  'Livno III',
#  'Llanic',
#  'Lokori',
#  'Lola Sayu',
#  'Lolet',
#  'Lonera',
#  'Lothal',
#  'Lotho Minor',
#  'Luprora',
#  'Lutrillia',
#  'Lysatra',
#  'Mahranee',
#  'Malachor',
#  'Malastare',
#  'Maldo Kreis',
#  'Malian',
#  'Malpaz',
#  'Manaan',
#  'Mandalore',
#  'Mannius Eight',
#  'Manpha',
#  'Marca',
#  'Mardona III',
#  'Maridun',
#  'Marleyvane',
#  'Massoss',
#  'Mataou',
#  'Mathas',
#  'Mearalis II',
#  'Megalox Beta',
#  "Mek'tradi",
#  'Merj',
#  'Merokia',
#  'Metellos',
#  'Mexeluine',
#  'Midarr',
#  'Midgor',
#  'Mijos',
#  'Mikkia',
#  'Milvayne',
#  'Mimban',
#  'Minfar',
#  'Mirial',
#  'Mirrin Prime',
#  'Miser',
#  'Mokivj',
#  'Moldour',
#  'Molos',
#  'Mon Cala',
#  'Mooga',
#  'Moorja',
#  'Moraband',
#  'Moraga',
#  'Morak',
#  'Mordal',
#  'Morellia',
#  'Mountain (planet)',
#  'Mrinzebon',
#  'Mulita',
#  'Murkhana',
#  'Mustafar',
#  'Muunilinst',
#  'Mydasos',
#  'Mygeeto',
#  'Mykapo',
#  'Myomar',
#  'Naalol',
#  'Naboo',
#  'Nacon',
#  'Nacronis',
#  'Nag Ubdur',
#  'Najan-Rovi',
#  'NaJedha',
#  'Najra-Va',
#  'Nakadia',
#  'Nal Hutta',
#  'Nam Chorios',
#  "Nanth'ri",
#  'Naporar',
#  'Nar Kanji',
#  'Naraka',
#  'Narq',
#  'Navlaas',
#  'Necropolis',
#  'Neelanon',
#  'Neimoidia',
#  'Nelgenam',
#  'Nelvaan',
#  'Nepotis',
#  'Neral',
#  'Neralus',
#  'Neskar',
#  'Netalych',
#  'Nettehi',
#  'Nevarro',
#  'Nimban',
#  'Ningoth',
#  'Nixus',
#  'Nixus (Haileap system)',
#  'Noctu',
#  'Nordis Prime',
#  'Nothoiin',
#  'Noult',
#  'Numidian Prime',
#  'Nyriaan',
#  "N'Zoth",
#  'Oba Diah',
#  'Obroa-skai',
#  'Ocahont',
#  'Odona',
#  'Ogem',
#  'Oktaro',
#  'Oliu',
#  'Omereth',
#  'Onderon',
#  'Onod I',
#  'Ontotho',
#  'Oon',
#  'Oosalon',
#  'Orchis',
#  'Ord Cestus',
#  'Ord Mantell',
#  'Ord Mynock',
#  'Ord Pardron',
#  'Ord Tiddell',
#  'Ordo',
#  'Orish',
#  'Orn Kios',
#  'Orondia',
#  'Orra',
#  'Orto',
#  'Orto Plutonia',
#  'Oru',
#  'Oshira',
#  'Osseriton',
#  'Ossus',
#  'Oulanne',
#  'Ovanis',
#  'Pacara',
#  'Pagodon',
#  'Pamarthe',
#  "Pam'ba",
#  'Pandem Nai',
#  'Panna',
#  'Parau VI',
#  'Parnassos',
#  'Pasaana',
#  'Pasher',
#  'Pastoria',
#  'Patitite Pattuna',
#  'Patrolia',
#  'Paucris Major',
#  'Pendarr III',
#  'Perimako Major',
#  'Persis IX',
#  'Petrusia',
#  'Phateem',
#  'Phatrong',
#  'Pheryon',
#  'Philaxia',
#  'Phindar',
#  'Phorsa Gedd',
#  'Pii',
#  'Pijal',
#  'Pillio',
#  'Pion',
#  'Pipada',
#  'Pippip 3',
#  'Plexis',
#  'Plin Minor',
#  'Polis Massa',
#  'Pollillus',
#  'Polmanar',
#  'Polyneus',
#  'Ponemah Terminal',
#  'Pothor',
#  'Prefsbelt IV',
#  'Primea',
#  'Protobranch',
#  'Pujool',
#  'Pzandias',
#  'Qhulosk',
#  'Qualai',
#  'Quarmendy',
#  'Quarzite',
#  'Quell',
#  'Quermia',
#  'Ques',
#  'Quila',
#  'Quintil',
#  'Raddan',
#  'Radhii',
#  'Raithal',
#  'Rajtiri',
#  'Rakata Prime',
#  'Ralltiir',
#  'Rango Tan',
#  'Rapacc',
#  'Rattatak',
#  'Raxus Prime',
#  'Raxus Secundus',
#  'Raydonia',
#  'Raysho',
#  'Reamma',
#  'Refnu',
#  'Rekkana',
#  'Rendel',
#  'Rentor',
#  'Retta',
#  'Rhen Var',
#  'Rhinnal',
#  'Ridlay',
#  'Riflor',
#  'Rina Major',
#  'Ringo Vinda',
#  'Rinn',
#  'Rion',
#  'Riosa',
#  'Rishi',
#  'Risso',
#  'Roche',
#  'Rodia',
#  'Ronika',
#  'Routh',
#  'Rumitaka',
#  'Ruoss Minor',
#  'Rushan IX',
#  'Ruusan',
#  'Ryloth',
#  'Rystan',
#  'Safrifa',
#  'Saki',
#  'Saleucami',
#  'Salient I',
#  'Salient II',
#  'Salliche',
#  'Sammun',
#  'Samovar',
#  'Sanjin',
#  'Sarka',
#  'Sarrish',
#  'Sarvchi',
#  'Satotai',
#  'Savareen',
#  'Scarif',
#  'Scipio',
#  'Secundus Ando',
#  'Sedratis',
#  'Sedri',
#  'Sedri Minor',
#  'Seelos',
#  'Selonia',
#  'Sembla',
#  'Serelia',
#  'Serenno',
#  'Sergia',
#  'Serralonis',
#  'Sesid',
#  'Setor',
#  'Sevarcos',
#  'Seylott',
#  'Sha Qarot',
#  'Shadda-Bi-Boran',
#  'Shantipole',
#  'Shihon',
#  'Shili',
#  'Shownar',
#  'Shuraden',
#  'Shu-Torun',
#  'Sibensko',
#  'Sirpar',
#  'Sissubo',
#  'Skako',
#  'Skako Minor',
#  'Skaradosh',
#  'Skorii-Lei',
#  'Skuhl',
#  'Sleheyron',
#  'Soika',
#  'Solitair',
#  'Son-tuul',
#  'Sorgal 12',
#  'Sorgan',
#  'Spalex',
#  'Spira',
#  'Sposia',
#  'Sriluur',
#  'Sterdic IV',
#  'Stivic',
#  'Strokill Prime',
#  "Sturg Ganna's homeworld",
#  'Stygeon Prime',
#  'Suba',
#  'Subterrel',
#  'Sullust',
#  'Sunrise',
#  'Taanab',
#  "Tah'Nuhna",
#  'Tais Brabbo',
#  'Takobo',
#  'Takodana',
#  'Talus',
#  'Tammuz-an',
#  'Tamsye Prime',
#  'Tangenine',
#  'Tansyl 5',
#  'Taris',
#  'Tarsunt (planet)',
#  'Tatooine',
#  'Taul',
#  'Tehar',
#  'Tei-Untis',
#  'Telerath',
#  'Tepasi',
#  'Teralov',
#  'Teth',
#  'Tevel',
#  'Thabeska',
#  'Theron',
#  'Thisspias',
#  'Tholoth',
#  'Thrad',
#  'Throffdon',
#  'Thunder',
#  'Thune',
#  'Thustra',
#  'Thyferra',
#  'Tibrin',
#  'Tierfon',
#  'Tiferep Major',
#  'Tiikae',
#  'Tinnel IV',
#  'Tish',
#  'Tokmia',
#  'Toledian',
#  'Toola',
#  'Toprawa',
#  'Touksingal',
#  'Toydaria',
#  'Tralus',
#  'Trandosha',
#  'Trasse',
#  'Triffis',
#  'Trionak',
#  'Trivar II',
#  'Troiken',
#  'Troithe',
#  'Trymant IV',
#  'Tsevuka',
#  'Tund',
#  'Tureen VII',
#  'Twon Ketee',
#  'Tyegin',
#  'Tynna',
#  'Tython',
#  'Ubardia',
#  'Ubduria',
#  'Uchinao',
#  'Ukio',
#  'Umbara',
#  'Umme',
#  'Unidentified agricultural planet',
#  'Unidentified backwater icy planet',
#  'Unidentified city planet',
#  'Unidentified desert planet',
#  'Unidentified forest planet',
#  'Unidentified Gank homeworld',
#  'Unidentified gas giant (Sentinel Base)',
#  'Unidentified green planet',
#  'Unidentified jungle planet',
#  'Unidentified lava planet',
#  'Unidentified night world',
#  'Unidentified ocean planet',
#  'Unidentified Outer Rim planet (Jenra)',
#  'Unidentified Outer Rim planet (Jul Jerjerrod)',
#  'Unidentified Outer Rim planet (Slitherette)',
#  'Unidentified planet (Bylsma)',
#  'Unidentified planet (Cora Vessora)',
#  'Unidentified planet (Dene Gois Cluster)',
#  'Unidentified planet (Dragon Void Run)',
#  'Unidentified planet (Drengir)',
#  'Unidentified planet (droid uprising)',
#  'Unidentified planet (Eeth Koth)',
#  'Unidentified planet (Emil Graf)',
#  'Unidentified planet (Freidal)',
#  'Unidentified planet (Han Solo)',
#  'Unidentified planet (Havoc Outpost)',
#  'Unidentified planet (Horizon Base)',
#  'Unidentified planet (Ilum system)',
#  'Unidentified planet (Jaxxon)',
#  'Unidentified planet (Kanina Nico)',
#  'Unidentified planet (Klikklak)',
#  'Unidentified planet (Lexim)',
#  'Unidentified planet (Live islands)',
#  "Unidentified planet (Lupr'or)",
#  'Unidentified planet (Magna Tolvan)',
#  'Unidentified planet (Monsua Nebula)',
#  'Unidentified planet (Neijaian)',
#  'Unidentified planet (Nes Ukul)',
#  'Unidentified planet (Outer Rim Territories)',
#  'Unidentified planet (Poe Dameron)',
#  'Unidentified planet (Raada)',
#  'Unidentified planet (sabacc)',
#  'Unidentified planet (Sunshi system)',
#  'Unidentified planet (Tholme and Ventress)',
#  "Unidentified planet (Thrawn's exile)",
#  'Unidentified planet (Vagadarr system)',
#  'Unidentified purple gas giant',
#  'Unidentified ringed planet',
#  'Unidentified Snee homeworld',
#  'Unidentified Squamatan homeworld',
#  'Unidentified uninhabited volcanic planet',
#  'Uquine',
#  'Urajab',
#  'Urch',
#  'Uro',
#  'Ushruu',
#  'Utapau',
#  'Uvena Prime',
#  'Uyter',
#  'Valahari',
#  'Vallt',
#  'Valo',
#  'Valron',
#  'Valtos',
#  'Vandor',
#  'Vanqor',
#  'Vardos',
#  'Varkana',
#  'Var-Shaa',
#  'Vashka',
#  'Vassek',
#  'Velusia',
#  'Vendaxa',
#  'Vernid',
#  'Veros',
#  'Vertseth',
#  'Verzan',
#  'Vespaara',
#  'Vetine',
#  'Viamarr',
#  'Vir Aphshire',
#  'Virujansi',
#  'Vixnix',
#  'Vjun',
#  'Vlemoth Port',
#  'Vodran',
#  'Vorlag',
#  'Vrant Tarnum',
#  'Vrogas Vas',
#  'Vulpter',
#  'Vurdon Ka',
#  'Vyndal',
#  'Wadi Raffa',
#  'Warlentta',
#  'Watassay',
#  'Water (planet)',
#  'Wecacoe',
#  'Weik',
#  'Wellspring of Life',
#  'Whiforla II',
#  'Wick 111',
#  'Wind',
#  'Wobani',
#  'Wrea',
#  'Wynkahthu',
#  'Xais',
#  'Xala',
#  'Xendek',
#  'Xibariz',
#  'Xirl',
#  'Xorrn',
#  'Yabol Opa',
#  "Yag'Dhul",
#  'Yakorki',
#  'Yar Togna',
#  'Yarma',
#  'Yavin Prime',
#  'Yeksom',
#  'Yerbana',
#  'Ylesia',
#  'Yout',
#  'Yungbrii',
#  'Zastiga',
#  'Zav Alox',
#  'Zeffo',
#  'Zeitooine',
#  'Zhanox',
#  'Zoh',
#  'Zolan',
#  'Zoph',
#  'Zygerria',
#  'Zyzar']

# %% [markdown]
# We have succesfully created list of all Star Wars planets. Now, we want to pick one representative planet and determine the attributes that we would like to collect.
#
# Probably the most popular planet in Star Wars universe is planet **Tatooine**, the home planet of Skywalker family known for it's characteristic two suns. Let's check it's <a href="https://starwars.fandom.com/wiki/Tatooine">wiki</a>.
#
# After inspecting Tatooine's wiki page, I noticed that every element describing planet in infobox has the same html class, and attribute called "data-source" which describes it's name. This is the key by which we will collect list of all Tatooine attributes.

# %%
page2 = requests.get('https://starwars.fandom.com/wiki/Tatooine')
soup2 = BeautifulSoup(page2.content, 'html.parser')

# %%
#listing all "data source" tags from site
attributes = [i['data-source'] for i in soup2.find_all(attrs={'class':'pi-item pi-data pi-item-spacing pi-border-color'})]
attributes
# Out:
# ['region',
#  'sector',
#  'system',
#  'suns',
#  'position',
#  'moons',
#  'coord',
#  'routes',
#  'distance',
#  'lengthday',
#  'lengthyear',
#  'class',
#  'diameter',
#  'atmosphere',
#  'climate',
#  'terrain',
#  'water',
#  'interest',
#  'flora',
#  'fauna',
#  'species',
#  'otherspecies',
#  'language',
#  'population',
#  'cities',
#  'imports',
#  'exports',
#  'affiliation']

# %% [markdown]
# This quite a lot of information, but for my desired data set - the more the better. I assume no planet will have more information than Tatooine (and if some of them will, it's not that big of a deal considering how detailed information we already want to gather). Most of them will have less data.
#
# Now we need to write a code, which will open every planet wiki site, gather available data about our attributes (skip if there are none) and write it down as list of dictionaries (one dictionary for each planet). This will be the base for our planet data frame.
#
# Every wookieepedia page has the same url with different ending. This ending is the name of the link, so the planet name we collected in our list. In our loop we will create a **new url every next iteration with new ending** (from list of planets). In every iteration we need to create second loop that will **collect data by every element from our attribute list**. Attribute data will be written down in **attributeSet dictionary**, and appended to **planetsData list**.
#
# Let's also check **how long** it will take to gather all requested data.

# %%
#creating list of dictionaries - our data for planets DataFrame object
planetsData = []
#time marker to measure how long does it take to collect all requested data
start_full = time.time()

for planet in planets:
    attributeSet = {}
    start = time.time()
    #creating path to planet site
    url = 'https://starwars.fandom.com/wiki/'+planet
    pageSet = requests.get(url)
    soupSet = BeautifulSoup(pageSet.content, 'html.parser')
    
    #getting all data about attributes from planet sites
    for attribute in attributes:
        data = soupSet.find(attrs={'data-source': attribute})
        if data is not None:
            attributeSet[attribute] = data.find(attrs={'class':'pi-data-value pi-font'}).get_text()
    planetsData.append(attributeSet)
    
print('Data uploaded!\nIt took {} minutes to collect all requested data'.format(round((time.time()-start_full)/60,1)))
# Out:
# Data uploaded!
# It took 23.9 minutes to collect all requested data

# %% [markdown]
# Success! It took a while but we finnaly have all data we need. Let's create a data frame and check how it looks.

# %%
planetsFrame = pd.DataFrame(planetsData, index=planets)
planetsFrame.head()
# Out:
#                                              affiliation  \
# 5251977              Alliance to Restore the Republic[1]
# Aargonar           Confederacy of Independent Systems[1]
# Ab Dalis             Alliance to Restore the Republic[2]
# Abafar                 Unallied (Separatist presence)[1]
# Abednedo (planet)      Galactic Empire[3]New Republic[5]
#
#                                                             interest  \
# 5251977                                                          NaN
# Aargonar                                 Aargonar Separatist base[1]
# Ab Dalis           Keftia district[1]Rendezvous Point Lambda-Four[2]
# Abafar                   Rhydonium mining installation[9]The Void[1]
# Abednedo (planet)                                     Oddy's home[2]
#
#                                      region              system  \
# 5251977                                 NaN                 NaN
# Aargonar                                NaN                 NaN
# Ab Dalis           Outer Rim Territories[1]  Ab Dalis system[1]
# Abafar             Outer Rim Territories[1]    Abafar system[3]
# Abednedo (planet)               Colonies[1]                 NaN
#
#                              routes           class     atmosphere    terrain  \
# 5251977                         NaN             NaN            NaN        NaN
# Aargonar                        NaN             NaN            NaN        NaN
# Ab Dalis             A hyperlane[1]  Terrestrial[1]  Breathable[2]  Swamps[1]
# Abafar                          NaN             NaN  Breathable[7]  Desert[1]
# Abednedo (planet)  Corellian Run[1]             NaN            NaN        NaN
#
#                                population             sector  ...  \
# 5251977                               NaN                NaN  ...
# Aargonar                              NaN                NaN  ...
# Ab Dalis           Over twenty million[1]                NaN  ...
# Abafar                                NaN  Sprizen sector[2]  ...
# Abednedo (planet)                     NaN                NaN  ...
#
#                        species coord moons language position flora lengthday  \
# 5251977                    NaN   NaN   NaN      NaN      NaN   NaN       NaN
# Aargonar                   NaN   NaN   NaN      NaN      NaN   NaN       NaN
# Ab Dalis                   NaN   NaN   NaN      NaN      NaN   NaN       NaN
# Abafar                     NaN   NaN   NaN      NaN      NaN   NaN       NaN
# Abednedo (planet)  Abednedo[3]   NaN   NaN      NaN      NaN   NaN       NaN
#
#                   lengthyear imports distance
# 5251977                  NaN     NaN      NaN
# Aargonar                 NaN     NaN      NaN
# Ab Dalis                 NaN     NaN      NaN
# Abafar                   NaN     NaN      NaN
# Abednedo (planet)        NaN     NaN      NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# As we can see, data contains very typical wiki index boxes (\[*number*\]). From what I see, every attribute has one. We need to **define a function** that will **clear our data from those indexes** and that will **insert comma and space when there are more elements in the cell**. We will do so by converting left "\[" bracket sign to righ "\]" bracket sign, splitting the string by it and creating new list containing only even elements (without internal numbers). If there are two elements in our cell (so originally one element and index) we want to return only first element. If there are more than two elements (so originally more than one), we will return list joined by comma and space (", "). If there is no attribute (NaN value) we return the same value.

# %%
def clear_data(data):
    if pd.isna(data):
        return data
    dataSplit = str(data).replace('[',']').split(']')
    dataCleared = [dataSplit[i] for i in range(len(dataSplit)) if i%2==0]
    if len(dataCleared) > 2:
        return ', '.join(dataCleared).rstrip()
    return dataCleared[0].rstrip()

# %% [markdown]
# Now let's apply our function on all elements of planetsFrame.

# %%
planetsFrame = planetsFrame.applymap(clear_data)
planetsFrame.head(10)
# Out:
#                                               affiliation  \
# 5251977                  Alliance to Restore the Republic
# Aargonar               Confederacy of Independent Systems
# Ab Dalis                 Alliance to Restore the Republic
# Abafar                     Unallied (Separatist presence)
# Abednedo (planet)          Galactic Empire, New Republic,
# Abelor                                                NaN
# Abregado-rae                                          NaN
# Absanz             Galactic Empire, Sienar Fleet Systems,
# Actlyon                                               NaN
# Aeos Prime               Alliance to Restore the Republic
#
#                                                             interest  \
# 5251977                                                          NaN
# Aargonar                                    Aargonar Separatist base
# Ab Dalis              Keftia district, Rendezvous Point Lambda-Four,
# Abafar                      Rhydonium mining installation, The Void,
# Abednedo (planet)                                        Oddy's home
# Abelor                                                           NaN
# Abregado-rae          Unidentified aquarium, Abregado-Rae Spaceport,
# Absanz                                  Sienar Fleet Systems factory
# Actlyon                                                          NaN
# Aeos Prime         Aeos Prime rebel outpost, Unidentified Aeosian...
#
#                                                     region           system  \
# 5251977                                                NaN              NaN
# Aargonar                                               NaN              NaN
# Ab Dalis                             Outer Rim Territories  Ab Dalis system
# Abafar                               Outer Rim Territories    Abafar system
# Abednedo (planet)                                 Colonies              NaN
# Abelor               Mid Rim Territories, Western Reaches,              NaN
# Abregado-rae                                   Core Worlds  Abregado system
# Absanz                                                 NaN              NaN
# Actlyon            Outer Rim Territories, Western Reaches,              NaN
# Aeos Prime                           Outer Rim Territories      Aeos system
#
#                               routes        class  atmosphere    terrain  \
# 5251977                          NaN          NaN         NaN        NaN
# Aargonar                         NaN          NaN         NaN        NaN
# Ab Dalis                 A hyperlane  Terrestrial  Breathable     Swamps
# Abafar                           NaN          NaN  Breathable     Desert
# Abednedo (planet)      Corellian Run          NaN         NaN        NaN
# Abelor                           NaN  Terrestrial         NaN        NaN
# Abregado-rae       Rimma Trade Route          NaN         NaN        NaN
# Absanz                           NaN          NaN  Breathable    Deserts
# Actlyon                          NaN  Terrestrial  Breathable  Mountains
# Aeos Prime                       NaN  Terrestrial  Breathable    Islands
#
#                             population          sector  ...   species coord  \
# 5251977                            NaN             NaN  ...       NaN   NaN
# Aargonar                           NaN             NaN  ...       NaN   NaN
# Ab Dalis           Over twenty million             NaN  ...       NaN   NaN
# Abafar                             NaN  Sprizen sector  ...       NaN   NaN
# Abednedo (planet)                  NaN             NaN  ...  Abednedo   NaN
# Abelor                             NaN             NaN  ...       NaN   NaN
# Abregado-rae                       NaN             NaN  ...       NaN  K-13
# Absanz                             NaN             NaN  ...       NaN   NaN
# Actlyon                            NaN             NaN  ...       NaN   NaN
# Aeos Prime                         NaN             NaN  ...   Aeosian   NaN
#
#                   moons language position flora lengthday lengthyear imports  \
# 5251977             NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Aargonar            NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Ab Dalis            NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Abafar              NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Abednedo (planet)   NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Abelor              NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Abregado-rae        NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Absanz              NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Actlyon             NaN      NaN      NaN   NaN       NaN        NaN     NaN
# Aeos Prime          NaN      NaN      NaN   NaN       NaN        NaN     NaN
#
#                   distance
# 5251977                NaN
# Aargonar               NaN
# Ab Dalis               NaN
# Abafar                 NaN
# Abednedo (planet)      NaN
# Abelor                 NaN
# Abregado-rae           NaN
# Absanz                 NaN
# Actlyon                NaN
# Aeos Prime             NaN
#
# [10 rows x 28 columns]

# %% [markdown]
# Looks much better. First part done, now let's jump into our real life planets.
#
# The category we will focus on here is **exoplanets**, so planets that exist outside of our solar system. The representative planet however will be Earth, since it has the biggest set of attributes and data. We will check on <a href="https://en.wikipedia.org/wiki/Earth">Earth wikipedia site</a> and decide which attributes we would like to collect.
#
# After inspecting the site I found anouther dependency in attribute names. All of them have attribute **"class"** set as **"infobox-label"**.

# %%
earthPage = requests.get('https://en.wikipedia.org/wiki/Earth')
earthSoup = BeautifulSoup(earthPage.content, 'html.parser')

# %%
for i in earthSoup.find_all(attrs={"class":"infobox-label"}):
    print(i.get_text())
# Out:
# Alternative names
# Adjectives
# Aphelion
# Perihelion
# Semi-major axis
# Eccentricity
# Orbital period
# Average orbital speed
# Mean anomaly
# Inclination
# Longitude of ascending node
# Time of perihelion
# Argument of perihelion
# Satellites
# Mean radius
# Equatorial radius
# Polar radius
# Flattening
# Circumference
# Surface area
# Volume
# Mass
# Mean density
# Surface gravity
# Moment of inertia factor
# Escape velocity
# Synodic rotation period
# Sidereal rotation period
# Equatorial rotation velocity
# Axial tilt
# Albedo
# Surface equivalent dose rate
# Surface pressure
# Composition by volume

# %% [markdown]
# This time I won't be needing most of this data. From our exoplanets I would like to see only this data, that can be useful in comparing to Star Wars planets data frame created earlier. I noticed some attributes that can correspond with each other:
#
# | Exoplanets | Star Wars planets |
# | --- | --- |
# | Satellites | moons|
# | Orbital period | lengthday |
# | Rotation period | lengthyear |
# | Mean radius | diameter |
#
# Additionaly, I noticed that on other planets we have also **"Star"** attribute (not present on Earth, maybe it was too obvious). This attribute corresponds with **"suns"** attribute from Star Wars planets. So we will add "Stars" to our attribute list as well.
#
# We will call this one attributesEP (EP from ExoPlanets), so we can distinguish them.

# %%
attributesEP = ['Star', 'Satellites', 'Orbital period', 'Rotation period', 'Mean radius']

# %% [markdown]
# Now we need exoplanets list. Sadly, there is no single list on wikipedia. There are exoplanets list divided into different categories. I have chosen lists of exoplanets by method of discovery (5 sites). List of this sites will be our basis for obtaining names of exoplanets.

# %%
exoplanetPages = ['https://en.wikipedia.org/wiki/List_of_transiting_exoplanets',
              'https://en.wikipedia.org/wiki/List_of_exoplanets_detected_by_radial_velocity',
              'https://en.wikipedia.org/wiki/List_of_exoplanets_detected_by_microlensing',
              'https://en.wikipedia.org/wiki/List_of_exoplanets_detected_by_timing',
              'https://en.wikipedia.org/wiki/List_of_directly_imaged_exoplanets']

# %% [markdown]
# There are also multiple tables on those sites - so how do we extract data from desired table? Looking at html code we can see, that exoplanets table is the only table that have **"sortable" value** in **"class" attribute**. This is our key.
# There are also **"dead" links** present here (exoplanets which don't have their sites yet). While creating our list we want to skip those links  - they have **"page does not exist"** string in their title.
#
# After gathering data we will convert our list to data series object, so we can easily apply **"unique" method** on it, making sure there are no duplicates there.

# %%
exoplanets = []
for url in exoplanetPages:
    pageEP = requests.get(url)
    soupEP = BeautifulSoup(pageEP.content, 'html.parser') 
    dataEP = []
    
    for table in soupEP.find_all('table'):
        if 'sortable' in table.get('class'):
            dataEP = [i.find('a').get('title') for i in table.find_all('td') if i.find('a') and i.find('a').get('title') is not None and "page does not exist" not in i.find('a').get('title')]
        exoplanets += dataEP
exoplanets = pd.Series(exoplanets)
exoplanets = exoplanets.unique()
exoplanets
# Out:
# array(['Kepler-42c', '55 Cancri e', 'WASP-19b', 'WASP-43b', 'Kepler-10b',
#        'COROT-7b', 'WASP-18b', 'WASP-12b', 'OGLE-TR-56b', 'HAT-P-23b',
#        'Kepler-42', 'WASP-33b', 'TrES-3b', 'HAT-P-36b', 'WASP-4b',
#        'WASP-46b', 'OGLE-TR-113b', 'Kepler-17b', 'COROT-1b', 'COROT-14b',
#        'WASP-36b', 'GJ 1214 b', 'Kepler-9d', 'WASP-64b', 'WASP-5b',
#        'OGLE-TR-132b', 'WASP-52b', 'COROT-2b', 'SWEEPS-11', 'WASP-3b',
#        'Kepler-41b', 'Kepler-42d', 'COROT-18b', 'WASP-50b', 'WASP-48b',
#        'HAT-P-32b', 'WASP-2b', 'HAT-P-7b', 'HD 189733 b', 'WASP-14b',
#        'WASP-24b', 'WASP-44b', 'KOI-254b', 'TrES-2b', 'OGLE2-TR-L9b',
#        'WASP-1b', 'XO-2b', 'Gliese 436 b', 'WASP-32b', 'COROT-21b',
#        'WASP-26b', 'HAT-P-16b', 'Kepler-21b', 'HAT-P-5b', 'WASP-49b',
#        'WASP-57b', 'COROT-12b', 'HAT-P-20b', 'HD 149026 b', 'HAT-P-3b',
#        'HAT-P-13b', 'COROT-11b', 'KOI-135b', 'TrES-1b', 'WASP-41b',
#        'HAT-P-4b', 'HAT-P-8b', 'WASP-10b', 'OGLE-TR-10b', 'WASP-16b',
#        'WASP-45b', 'WASP-35b', 'XO-3b', 'HAT-P-22b', 'HAT-P-12b',
#        'Kepler-4b', 'Kepler-6b', 'HAT-P-24b', 'WASP-6b', 'WASP-31b',
#        'WASP-28b', 'HAT-P-33b', 'Kepler-18b', 'Kepler-8b', 'HD 209458 b',
#        'WASP-22b', 'Kepler-5b', 'TrES-4b', 'WASP-37b', 'COROT-23b',
#        'HAT-P-25b', 'OGLE-TR-211b', 'Kepler-20b', 'WASP-54b',
#        'WASP-11b/HAT-P-10b', 'WASP-17b', 'WASP-15b', 'WASP-25b',
#        'COROT-17b', 'WASP-61b', 'HAT-P-6b', 'COROT-19b', 'WASP-69b',
#        'Lupus-TR-3b', 'WASP-29b', 'HAT-P-9b', 'XO-1b', 'OGLE-TR-182b',
#        'HAT-P-19b', 'OGLE-TR-111b', 'COROT-13b', 'COROT-5b', 'WASP-39b',
#        'WASP-47b', 'WASP-66b', 'HAT-P-21b', 'XO-4b', 'XO-5b', 'SWEEPS-04',
#        'HAT-P-26b', 'COROT-3b', 'WASP-60b', 'WASP-34b', 'WASP-21b',
#        'WASP-13b', 'WASP-62b', 'WASP-63b', 'Kepler-12b', 'HAT-P-1b',
#        'WASP-55b', 'WASP-56b', 'WASP-67b', 'HAT-P-14b', 'Kepler-7b',
#        'HAT-P-11b', 'Kepler-15b', 'WASP-7b', 'WASP-42b', 'WASP-58b',
#        'COROT-16b', 'HAT-P-18b', 'HAT-P-2b', 'Kepler-33b', 'HAT-P-29b',
#        'Kepler-32b', 'Kepler-28b', 'Kepler-20e', 'COROT-8b', 'Kepler-25b',
#        'Kepler-14b', 'WASP-38b', 'Kepler-40b', 'Kepler-23b',
#        'Kepler-223e', 'Kepler-18c', 'WASP-59b', 'Kepler-24b', 'WASP-8b',
#        'Kepler-32c', 'COROT-6b', 'Kepler-28c', 'COROT-20b', 'COROT-4b',
#        'Kepler-19b', 'HD 97658 b', 'KOI-730c', 'KIC 10905746 b',
#        'Kepler-11b', 'Kepler-29b', 'HAT-P-17b', 'Kepler-23c',
#        'Kepler-20c', 'HAT-P-15b', 'Kepler-26b', 'Kepler-24c',
#        'Kepler-25c', 'Kepler-11c', 'Kepler-33c', 'COROT-10b',
#        'Kepler-29c', 'KOI-730b', 'Kepler-18d', 'Kepler-27b', 'Kepler-9b',
#        'Kepler-20f', 'Kepler-223d', 'Kepler-31b', 'HD 17156 b',
#        'Kepler-33d', 'Kepler-11d', 'Kepler-30b', 'Kepler-27c',
#        'Kepler-33e', 'Kepler-11e', 'Kepler-9c', 'Kepler-33f',
#        'Kepler-31c', 'Kepler-10c', 'Kepler-11f', 'Kepler-943b',
#        'Kepler-30c', 'Kepler-20d', 'Kepler-991b', 'COROT-9b',
#        'HD 80606 b', 'Kepler-11g', 'Kepler-35b', 'Kepler-30d',
#        'Kepler-16b', 'Kepler-34b', 'Kepler-22b', 'Kepler-1647b',
#        'Kepler-560b', 'Kepler-1649b', 'Kepler-1649c', 'Kepler-1652b',
#        'Kepler-1544 b', 'Gliese 876 d', 'Santamasa', 'GJ 3634 b',
#        'Gliese 581e', 'Tau Boötis b', 'COROT-7c', '51 Pegasi b',
#        'Upsilon Andromedae b', 'Gliese 581b', 'Gliese 667 Cb',
#        'Gliese 581c', 'HD 38529 b', '55 Cancri b', 'Gliese 667 Cc',
#        'Gliese 876 c', '55 Cancri c', 'Gliese 876 b', 'Gliese 581d',
#        'HD 20794 d', 'Gliese 876 e', 'HD 60532 b', 'Upsilon Andromedae c',
#        '55 Cancri f', 'Epsilon Reticuli b', 'Iota Draconis b',
#        'HD 147513 b', 'Pollux b', 'HD 60532 c', 'Mu Arae b',
#        'HD 128311 c', 'HD 10647 b', 'Upsilon Andromedae d', 'HAT-P-17c',
#        '47 Ursae Majoris c', 'Epsilon Eridani b', '55 Cancri d',
#        '47 Ursae Majoris d', 'HD 156668 b', 'HD 10180 b', 'HD 212301 b',
#        'HD 73256 b', 'HD 63454 b', 'HD 83443 b', 'HD 46375 b',
#        'HD 179949 b', 'HD 187123 b', 'HD 134060 b', 'HD 330075 b',
#        'HD 88133 b', 'HD 2638 b', 'BD-10°3166 b', 'HD 75289 b',
#        'HD 219828 b', 'HD 215497 b', 'HD 76700 b', 'HD 149143 b',
#        'HD 47186 b', 'HD 102195 b', 'HD 125612 c', '61 Virginis b',
#        'HD 40307 b', 'Gliese 674 b', 'HD 49674 b', 'HD 109749 b',
#        'HD 7924 b', 'HD 10180 c', 'HD 1461 b', 'HD 118203 b',
#        'HD 68988 b', 'HD 168746 b', 'HD 102956 b', 'HIP 14810 b',
#        'HD 185269 b', 'Gliese 433 b', 'HD 217107 b', 'HD 96700 b',
#        'HD 69830 b', 'Gliese 176 b', 'HD 181433 b', 'HD 40307 c',
#        'Mu Arae c', 'HD 125595 b', 'HD 130322 b', 'HD 108147 b',
#        'HD 136352 b', 'HD 93385 b', 'HD 1461 c', 'HD 179079 b',
#        'HD 4308 b', 'Gliese 86 b', 'HD 10180 d', '83 Leonis Bb',
#        'Gliese 777 c', 'HD 16417 b', 'HD 27894 b', 'HD 33283 b',
#        'HD 195019 Ab', '82 G. Eridani', 'HD 154088 b', 'HD 40307 d',
#        'HD 102117 b', 'HD 6434 b', 'HD 192263 b', 'HD 224693 b',
#        'HD 136352 c', 'HD 20781 b', 'HD 9446 b', 'HD 69830 c',
#        'HD 204313 c', 'HD 43691 b', 'HD 11964 c', '61 Virginis c',
#        'HIP 57050 b', 'HD 45652 b', 'HD 147018 b', 'HD 93385 c',
#        'HD 103197 b', 'HD 107148 b', 'HD 10180 e', 'HD 90156 b',
#        'HD 74156 b', 'HD 117618 b', 'HD 37605 b', 'HD 104067 b',
#        'HIP 12961 b', 'HD 168443 b', 'Gliese 370 b', '54 Piscium b',
#        'HD 121504 b', 'HD 101930 b', 'HD 178911 Bb', 'HR 7722 b',
#        'HD 163607 b', '79 Ceti b', 'HD 20781 c', 'HD 96700 c',
#        'HD 145377 b', 'Gliese 667 Cd', 'HD 136352 d', 'HD 177830 c',
#        'HIP 79431 b', '70 Virginis b', 'HD 216770 b', 'HD 52265 b',
#        'HD 102365 b', 'HD 208487 b', 'HD 10180 f', '61 Virginis d',
#        'HD 102272 b', 'GJ 3021 b', 'Xi Aquilae b', 'HD 231701 b',
#        'HD 93083 b', 'HIP 14810 c', 'HD 37124 b', 'HD 32518 b',
#        'HD 100655 b', 'HD 154672 b', 'HD 11506 c', 'HD 145457 b',
#        '91 Aquarii b', '41 Lyncis b', '14 Andromedae b', 'HD 73526 b',
#        'HD 9446 c', 'HD 155358 b', 'HD 69830 d', 'HD 104985 b',
#        'HD 75898 b', 'HD 82943 c', 'HD 169830 b', 'HD 218566 b',
#        'HD 45364 b', 'HD 8574 b', 'HD 89744 b', 'HD 202206 c',
#        '23 Librae b', 'HD 40979 b', 'HD 113538 b', 'HD 12661 b',
#        '4 Ursae Majoris b', 'HD 205739 b', 'BD+48 738 b', 'HD 175541 b',
#        'HD 59686 b', 'Mu Arae d', 'Iota Horologii b', 'HD 173416 b',
#        'HD 43197 b', 'HD 137388 b', 'HD 148427 b', 'HD 142 b',
#        'HD 210702 b', 'HD 45364 c', 'HD 122430 b', 'HIP 5158 b',
#        'HD 192699 b', 'HD 63765 b', 'HD 4313 b', 'HD 17092 b',
#        'HD 38283 b', 'HD 212771 b', 'HD 92788 b', 'HD 73526 c',
#        'Alpha Arietis b', 'HD 20868 b', 'HD 28185 b', 'HD 100777 b',
#        'HD 142415 b', 'HD 33564 b', 'HD 108874 b', 'HD 4203 b',
#        'HD 4208 b', 'HD 177830 b', 'HD 38858 b', 'HD 154857 b',
#        'HD 167042 b', 'Gamma1 Leonis b', 'HD 47536 b', 'HD 98219 b',
#        'HD 99109 b', 'HD 82943 b', 'HD 210277 b', 'HD 128311 b',
#        '24 Sextantis b', '94 Ceti b', 'HD 221287 b', 'HD 188015 b',
#        'HD 180902 b', 'HD 44219 b', 'HD 136418 b', '42 Draconis b',
#        'HD 9578 b', 'HD 96167 b', 'HD 153950 b', 'HD 20367 b',
#        'HD 114783 b', 'HD 125612 b', 'HD 240210 b', '11 Ursae Minoris b',
#        'HD 102272 c', 'Gliese 785 c', 'HD 4113 b', 'HD 155358 c',
#        'HD 171028 b', 'HD 215497 c', 'HD 222582 b', 'HD 20782 b',
#        'Epsilon Tauri b', 'Gliese 649 b', 'HD 10180 g', 'HD 164604 b',
#        'HD 206610 b', 'HD 65216 b', 'HD 200964 b', 'HD 7199 b',
#        'BD+20°2457 c', 'HD 183263 b', 'HD 141937 b', 'HD 41004 Ab',
#        'HD 181342 b', 'HD 5319 b', 'Gliese 317 b', 'HD 38801 b',
#        'HD 48265 b', 'HD 82886 b', 'Eta2 Hydri b', 'NGC 2423-3 b',
#        'HD 23079 b', 'HD 240237 b', 'Nu2 Canis Majoris b', 'HD 85390 b',
#        '16 Cygni Bb', 'HD 200964 c', 'Chi Virginis b', 'HD 156411 b',
#        'HD 70573 b', 'HD 114386 b', 'HD 131496 b', '24 Sextantis c',
#        'HD 37124 c', 'HD 45350 b', '6 Lyncis b', 'Gamma Cephei Ab',
#        'HD 213240 b', '81 Ceti b', 'HD 181720 b', 'HIP 14810 d',
#        'HD 181433 c', 'HD 132406 b', 'HD 159868 b', 'HD 187085 b',
#        'HD 16175 b', '18 Delphini b', 'HD 81040 b', 'HD 34445 b',
#        'HD 147018 c', 'HD 148156 b', 'HD 190647 b', 'HD 114386 c',
#        'HD 143361 b', 'Gliese 676 Ab', '109 Piscium b',
#        '47 Ursae Majoris b', 'HD 28254 b', 'HD 139357 b', 'HD 114729 b',
#        'HD 111232 b', 'HD 170469 b', 'HD 164922 b', 'HD 30562 b',
#        'HD 134060 c', 'HD 2039 b', 'HD 126614 Ab',
#        'Kappa Coronae Borealis b', 'HD 23127 b', 'HD 73267 b',
#        'HD 11506 b', 'HD 196050 b', 'HD 175167 b', 'HD 50554 b',
#        'Rho Indi b', 'HD 8535 b', 'HD 163607 c', 'HD 196885 Ab',
#        'HD 47186 c', 'Tau1 Gruis b', 'HD 12661 c', 'HD 86264 b',
#        'HD 171238 b', 'HD 86226 b', 'HD 132563 Bb', 'HD 23596 b',
#        'HD 113538 c', 'HD 108874 c', '14 Herculis b', 'HD 73534 b',
#        'HD 129445 b', 'HD 25171 b', 'HD 37124 d', 'Gliese 849 b',
#        'HD 142022 Ab', 'HD 204313 b', 'HD 11964 b', 'HD 79498 b',
#        'HD 66428 b', 'Pi Mensae b', 'HD 152079 b', 'HD 169830 c',
#        'HD 89307 b', 'HD 181433 d', 'HD 220689 b', 'HD 27631 b',
#        'HD 10180 h', 'HD 70642 b', 'Gliese 179 b', 'HD 290327 b',
#        'HD 74156 c', 'HD 47536 c', 'HD 6718 b', 'HD 117207 b',
#        'HD 37605 c', 'HD 87883 b', 'HD 30177 b', 'Gliese 777 b',
#        'HD 183263 c', 'HD 125612 d', 'HD 72659 b', 'HD 154345 b',
#        'HIP 70849 b', 'HD 24040 b', 'Gliese 832 b', 'HD 50499 b',
#        'HD 106515 Ab', 'Gliese 433 c', 'HD 220773 b', 'HD 187123 c',
#        'Upsilon Andromedae e', 'Mu2 Octantis b', 'Mu Arae e',
#        'HD 217107 c', 'HD 13931 b', 'HD 190984 b', '83 Leonis Bc',
#        '23 Librae c', '14 Herculis c', 'HD 166724 b', 'HD 98649 b',
#        'MOA-2007-BLG-192Lb', 'MOA-2007-BLG-400Lb', 'MOA-2008-BLG-310Lb',
#        'MOA-2009-BLG-387Lb', 'OGLE-2005-BLG-390Lb', 'OGLE-2006-BLG-109Lb',
#        'OGLE-2005-BLG-169Lb', 'OGLE-2007-BLG-368Lb',
#        'OGLE-2005-BLG-071Lb', 'OGLE-2006-BLG-109Lc',
#        'OGLE-2003-BLG-235Lb/MOA-2003-BLG-53Lb', 'MOA-2010-BLG-477Lb',
#        'MOA-2011-BLG-262L', 'Rogue planet', 'OGLE-2014-BLG-0124Lb',
#        'OGLE-2019-BLG-0551', 'SDSS J1228+1040 b', 'PSR J1719-1438 b',
#        'PSR B1257+12 A', 'PSR B1257+12 B', 'PSR B1257+12 C',
#        'PSR B0943+10 b', 'PSR B0943+10 c', 'HU Aquarii b',
#        'NY Virginis b', 'HW Virginis c', 'RR Caeli b', 'HU Aquarii c',
#        'NN Serpentis c', 'HW Virginis b', 'DP Leonis b', 'PSR B1620-26 b',
#        'Beta Pictoris b', '51 Eridani b', 'HR 8799 e', 'HR 8799 d',
#        'HR 8799 c', 'HR 8799 b', 'ROXs 42Bb', '2M1207b', '1RXS 1609 b',
#        'Fomalhaut b', 'LkCa 15 b', 'WD 0806-661 b', 'Ross 458(AB) c',
#        'HD 95086 b', 'Gliese 504 b', 'Kappa Andromedae b', 'HD 106906 b',
#        'GU Piscium b', 'HIP 65426 b', 'PDS 70 b', 'PDS 70 c', 'HD 203030',
#        '2MASS J2126–8140', 'Candidate 1', 'COCONUTS-2b'], dtype=object)

# %% [markdown]
# This is our list (or rather array) of exoplanets. Now we have everything we need to gather core data about attributes from each planet site.
#
# Similar as before, we will create a loop that will create and open site for each planet from our list, and then gather data about it's attributes. All attribute labels in infobox have **"infobox-label"** in **"class"** tag, and all corresponding data have **"infobox-data"** in **"class"** tag. This is how we will extract this data.
#
# Just like in previous scraping - let's also check **how long** did it take to collect all data.

# %%
exoplanetsData = []
start_full = time.time()

for exoplanet in exoplanets:
    attributeSetEP = {}
    start = time.time()
    
    #creating path to exoplanet site
    urlEP = 'https://en.wikipedia.org/wiki/'+exoplanet
    pageSetEP = requests.get(urlEP)
    soupSetEP = BeautifulSoup(pageSetEP.content, 'html.parser')
    
    #getting all data about attributes from planet site
    for attributeEP in attributesEP:
        #checking all table rows on planet site
        for i in soupSetEP.find_all('tr'):
            dataLabel = i.find(attrs={"class":"infobox-label"})
            dataInfo = i.find(attrs={"class":"infobox-data"})
            #checking if label exist and if it's text is our desired attribute
            if dataLabel is not None and dataLabel.get_text() == attributeEP:
                attributeSetEP[attributeEP] = dataInfo.get_text()                
    exoplanetsData.append(attributeSetEP)
    
print('Data uploaded!\nIt took {} minutes to collect all requested data'.format(round((time.time()-start_full)/60,1)))
# Out:
# Data uploaded!
# It took 4.6 minutes to collect all requested data

# %% [markdown]
# Great! Now let's create data frame and take a look.

# %%
exoplanetsFrame = pd.DataFrame(exoplanetsData, index=exoplanets)
exoplanetsFrame.head(10)
# Out:
#                      Star                                     Orbital period  \
# Kepler-42c      Kepler-42                             0.45328731±5*10−8[2] d
# 55 Cancri e   55 Cancri A               0.7365474 (± 0.0000014)[2] d17.677 h
# WASP-19b          WASP-19  0.78884 ± 0.0000003 d (18.9321600 ± 7.2×10−6 h...
# WASP-43b          WASP-43                     0.81347753 (± 0.00000071)[3] d
# Kepler-10b   Kepler-10[2]                             0.837495[1] d20.0999 h
# COROT-7b          CoRoT-7                           0.853585 ± 0.000024[1] d
# WASP-18b          WASP-18    0.94145455+0.00000087−0.00000132[3] d22.59487 h
# WASP-12b          WASP-12                                  1.091423 ± 3e-6 d
# OGLE-TR-56b    OGLE-TR-56                    1.211909 ± 0.000001 d29.08582 h
# HAT-P-23b             NaN                                                NaN
#
#                                          Mean radius
# Kepler-42c                       0.73±0.03[2] REarth
# 55 Cancri e                  1.875 ± 0.029[2] REarth
# WASP-19b                           1.386±0.032[2] RJ
# WASP-43b                       1.04 +0.07−0.09[4] RJ
# Kepler-10b                  1.47+0.03−0.02[3] REarth
# COROT-7b                    0.14 RJ1.58 ± 0.1 REarth
# WASP-18b                     1.106+0.072−0.054[2] RJ
# WASP-12b     1.900+0.057−0.055,[2] 1.736±0.056[3] RJ
# OGLE-TR-56b                           1.30 ± 0.05 RJ
# HAT-P-23b                                        NaN

# %% [markdown]
# Apparently we overestimated a bit the amount of available data. As we can see, all columns but Rotation period were filled. There is no data about rotation period in any of those exoplantes.
#
# Once again we will need to get rid of wiki indexes. This time we will make **new function**, because indexes does not appear at the end of the lines, but in the **middle** of them. **Comma and space is not good separator in this case**, we will modify previous funcion to join created lists with **no sign in between**.

# %%
def clear_data2(data):
    if pd.isna(data):
        return data
    dataSplit = str(data).replace('[',']').split(']')
    dataCleared = [dataSplit[i] for i in range(len(dataSplit)) if i%2==0]
    if len(dataCleared) > 2:
        return ''.join(dataCleared).rstrip()
    return dataCleared[0].rstrip()

# %%
exoplanetsFrame = exoplanetsFrame.applymap(clear_data2)
exoplanetsFrame.head(10)
# Out:
#                     Star                                     Orbital period  \
# Kepler-42c     Kepler-42                                  0.45328731±5*10−8
# 55 Cancri e  55 Cancri A                            0.7365474 (± 0.0000014)
# WASP-19b         WASP-19  0.78884 ± 0.0000003 d (18.9321600 ± 7.2×10−6 h...
# WASP-43b         WASP-43                          0.81347753 (± 0.00000071)
# Kepler-10b     Kepler-10                                           0.837495
# COROT-7b         CoRoT-7                                0.853585 ± 0.000024
# WASP-18b         WASP-18                   0.94145455+0.00000087−0.00000132
# WASP-12b         WASP-12                                  1.091423 ± 3e-6 d
# OGLE-TR-56b   OGLE-TR-56                    1.211909 ± 0.000001 d29.08582 h
# HAT-P-23b            NaN                                                NaN
#
#                                    Mean radius
# Kepler-42c                           0.73±0.03
# 55 Cancri e                      1.875 ± 0.029
# WASP-19b                           1.386±0.032
# WASP-43b                       1.04 +0.07−0.09
# Kepler-10b                      1.47+0.03−0.02
# COROT-7b              0.14 RJ1.58 ± 0.1 REarth
# WASP-18b                     1.106+0.072−0.054
# WASP-12b     1.900+0.057−0.055, 1.736±0.056 RJ
# OGLE-TR-56b                     1.30 ± 0.05 RJ
# HAT-P-23b                                  NaN

# %% [markdown]
# That's it. This data frame still doesn't look perfect, we have lots of different signs, descriptions, units etc. We will deal with this in the next part though during data cleaning. For now let's save our two data frames as csv files, that can be used later.

# %%
planetsFrame.to_csv('StarWarsPlanets.csv')
exoplanetsFrame.to_csv('Exoplanets.csv')

# %% [markdown]
# ## 4. Summary
#
# In this part we have succesfuly extracted (scraped) desired data from both wiki sites, creating two data sets containing selected information about planets in Star Wars fictional universe, and our universe. Based on this data I will try to create an algorithm that will compare those sets to find the most similar planets. First I will need to prepare data so they can have homogenous form and quantible values.
#
# Can't wait to see the outcome.
